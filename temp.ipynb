# %%
import jsonpickle

# %%
with open("./UMRDataset/raw/combined_data_annoted.json", 'r') as f:
    data = jsonpickle.decode(f.read())

# %%
data[0].keys()
# Out:
# dict_keys(['file', 'id', 'sentence', 'graph', 'predicate', 'variable', 'aspect', 'alignment', 'joined_sentence', 'mapping'])
